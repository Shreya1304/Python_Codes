# %%
words = ["hi",'hello','coot']
for word in words:
    print(word, len(word))
# Out:
# hi 2
# hello 5
# coot 4

# %%
for w in words:
    if len(w) > 2:
        words.insert(0,w)
        print(1)

# %%
a = words[:]

# %%
a
# Out:
# ['coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
#  'coot',
# ...

# %%
for i in range(2,20,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
a = list("Mary had a little lamb")
for i in range (len(a)):
    print(i,a[i])
# Out:
# 0 M
# 1 a
# 2 r
# 3 y
# 4
# 5 h
# 6 a
# 7 d
# 8
# 9 a
# 10
# 11 l
# 12 i
# 13 t
# 14 t
# 15 l
# 16 e
# 17
# 18 l
# 19 a
# 20 m
# 21 b

# %%
print(range(10))
# Out:
# range(0, 10)

# %%
print(list(range(5)))
# Out:
# [0, 1, 2, 3, 4]

# %%
str1=['a','b','c','d','e','f']

# %%
for s in range(0,len(str1),3):
    print(str1[s])
# Out:
# a
# d

# %%
List = ['G','E','E','K','S','F', 
        'O','R','G','E','E','K','S']
# Printing elements from 
# beginning till end 
Sliced_List = List[:] 
print("\nPrinting all elements using slice operation: ") 
print(Sliced_List)
# Out:
# Printing all elements using slice operation:
# ['G', 'E', 'E', 'K', 'S', 'F', 'O', 'R', 'G', 'E', 'E', 'K', 'S']

# %%
List
# Out:
# ['G', 'E', 'E', 'K', 'S', 'F', 'O', 'R', 'G', 'E', 'E', 'K', 'S']
